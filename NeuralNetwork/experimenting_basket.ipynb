# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import pandas as pd
import keras_tuner as kt
import tensorflow_datasets as tfds
import time

import sys
import os
py_file_location = "/content/drive/My Drive"
sys.path.append(os.path.abspath('/content/drive/MyDrive/NeuralNetwork'))
from models_hs import *
from trainer import *
from preprocess import *
from callbacks import *

# %% [markdown]
# # 0 Data

# %% [markdown]
# Read in data for each dimension and store as `pd.DataFrame`:

# %%
def get_dfs(dims, num_samples):
  dataframes_list = []
  for dim in dims:
      temp_df = pd.read_csv(f"/content/drive/MyDrive/data/{num_samples}_basket_data_{dim}.csv")
      temp_df = temp_df.drop(['Unnamed: 0'], axis=1)

      # move column with contract prices to the end
      cols = list(temp_df.columns.values) 
      cols.pop(cols.index('contract_price')) 
      temp_df = temp_df[cols+['contract_price']] 

      dataframes_list.append(temp_df)
  return dataframes_list

# %%
dims = [1, 4, 7, 10, 13, 16]
dataframes_list = get_dfs(dims, 1000)
dataframes_list[0]
# Out:
#      days_to_maturity  strike  volatility  mean_volatility  reversion  \
# 0                52.0   16.50    0.010564         0.041048   1.775966
# 1                21.0   49.50    0.039117         0.049353   1.540456
# 2                31.0   14.00    0.029249         0.006491   0.982883
# 3                18.0    8.70    0.038737         0.016305   2.372708
# 4                59.0   16.50    0.043640         0.038880   4.562963
# ..                ...     ...         ...              ...        ...
# 995              38.0   13.00    0.001502         0.046531   1.663993
# 996              85.0   15.00    0.042181         0.044124   0.302489
# 997              29.0    0.48    0.033398         0.005511   4.443828
# 998               7.0    9.50    0.004519         0.036562   2.277263
# 999              28.0   15.55    0.024088         0.020993   2.809961
#
#      vol_of_var      rate  Underlying_0     Rho_0  contract_price
# 0      0.058849  0.015002     17.332500 -0.333905       10.938264
# 1      0.489135  0.001440      9.260000 -0.129997        0.571392
# 2      0.224651  0.017221     16.414301 -0.462886        8.445650
# 3      0.329505  0.006641     15.892000 -0.141496        9.129831
# 4      0.706960  0.053901     11.277000 -0.379364       10.687387
# ..          ...       ...           ...       ...             ...
# 995    0.145838  0.001362     12.819120 -0.307483        6.298129
# 996    0.661890  0.018707     18.106250 -0.050286       24.277845
# 997    0.506015  0.002109     67.483701 -0.693189       65.758164
# 998    0.288585  0.003034     15.919620 -0.470891        7.345720
# 999    0.701111  0.002110     16.374000 -0.348144        7.016429
#
# [1000 rows x 10 columns]

# %% [markdown]
# Test model on 10000 samples with dim = 1:

# %%
dataframes_list_1 = get_dfs([1], 10000)
dataframes_list_1[0]
# Out:
#       days_to_maturity  strike  volatility  mean_volatility  reversion  \
# 0                 24.0   4.250    0.002046         0.050490   0.842923
# 1                119.0   5.050    0.050203         0.048482   2.676144
# 2                 10.0  15.000    0.012146         0.009763   0.952558
# 3                235.0  14.000    0.028765         0.038385   4.946453
# 4                130.0  16.300    0.010112         0.045151   0.474549
# ...                ...     ...         ...              ...        ...
# 9995              22.0   3.975    0.003293         0.047075   0.377678
# 9996               7.0  14.000    0.022504         0.025393   0.826864
# 9997              10.0  12.400    0.002174         0.040227   0.190017
# 9998             192.0   4.450    0.044043         0.030118   4.034105
# 9999             186.0   4.950    0.050072         0.007519   2.747140
#
#       vol_of_var      rate  Underlying_0     Rho_0  contract_price
# 0       0.631400  0.022602     58.010400 -0.320407       61.992674
# 1       0.702256  0.001616     39.998899 -0.102169       16.377944
# 2       0.693369  0.009901      5.080200 -0.394712        0.026545
# 3       0.012569  0.001688     13.283750 -0.471352        0.000000
# 4       0.218541  0.015604      4.440500 -0.101970        4.166032
# ...          ...       ...           ...       ...             ...
# 9995    0.601305  0.026390     12.496370 -0.421565       11.578677
# 9996    0.429884  0.001874     15.524250 -0.229666        3.513765
# 9997    0.502809  0.002174      4.612700 -0.243227        0.296504
# 9998    0.391629  0.025649     19.868500 -0.190983        2.275450
# 9999    0.129122  0.002014     13.366379 -0.737153       14.588851
#
# [10000 rows x 10 columns]

# %% [markdown]
# # 1 Training

# %%
import argparse
from pyexpat import model
import numpy as np
import tensorflow as tf

def model_builder_hs(dim,
            num_layers   = 2,
            hidden_units = [14,7],
            output_shape = (1,),
            activation = 'elu',
            regularizer = None,
            initializer = tf.keras.initializers.he_uniform(),
            final_activation = 'linear',
            dropout = None,
            batchnorm = False
            ): 
    """
    Returns a model for training and testing.  

    Args:
        - dim: int, basket size
        - num_layers: int, number of hidden layers
        - hidden_units: list of number of hidden units in each layer
        - output_shape: shape of the output data
        - activation: string, activation function
        - initializer: initializer for the weights
        - final_activation: string, activation function of final layer
        - dropout: list, dropout rate for each layer, default None
        - batchnorm: bool, specifies if batch normalization is used, default False 
    
    Output:  
        - model: tf.keras.Model, compiled if compile is True
    """  
    assert num_layers == len(hidden_units), "Number of hidden units must match number of layers"
    if dropout is not None:  
        assert num_layers == len(dropout), "Number of dropout rates must match number of layers"

    input_shape = (7 + 2*dim,)

    inputs = tf.keras.layers.Input(shape=input_shape)
    h = tf.keras.layers.Flatten()(inputs)

    for i, layer in enumerate(hidden_units):
        h = tf.keras.layers.Dense(layer, activation=activation, kernel_regularizer= regularizer,
                                  kernel_initializer = initializer)(h)
        if dropout:
            h = tf.keras.layers.Dropout(dropout[i])(h)
        if batchnorm:
            h = tf.keras.layers.BatchNormalization()(h)
    if final_activation is not None:
        outputs = tf.keras.layers.Dense(output_shape[0], activation=final_activation,
                                        kernel_initializer = initializer)(h)
    else:
        outputs = tf.keras.layers.Dense(output_shape[0], 
                                        kernel_initializer = initializer)(h)

    model = tf.keras.Model(inputs=inputs, outputs=outputs)  

    return model   


def tuned_model_hs(hp):
    """
    Returns a compiled hyperModel for keras tuner. 

    """  

    # defining a set of hyperparameters for tuning and a range of values for each
    num_layers = hp.Int('num_layers', min_value=1, max_value=5) 
    activation = hp.Choice('activation', ['elu','tanh', 'relu', 'sigmoid'])
    learning_rate = hp.Float('learning_rate', min_value=10**(-3), max_value=0.01)
    rate_decay = hp.Float('rate_decay', min_value=0.85, max_value=0.9995)
    l1_reg = hp.Float('l1_regularizer', min_value=10**(-8), max_value=10**(-6.5))
    l2_reg = hp.Float('l1_regularizer', min_value=10**(-8), max_value=10**(-6.5))
    batchnorm = hp.Boolean(name = 'batchnorm')
    
    hidden_units, dropouts = [],[]
    for i in range(num_layers):
        hidden_unit = hp.Int(f'units_{i+1}', min_value=5, max_value=7)
        hidden_units.append(hidden_unit)
        dropout = hp.Float(f'dropout_{i+1}', min_value=0.0, max_value=0.5, step=0.1)
        dropouts.append(dropout)

    model = model_builder_hs(dim,
                    num_layers = num_layers, 
                    hidden_units = hidden_units,
                    dropout = dropouts,
                    activation = activation,
                    batchnorm = batchnorm,
                    regularizer = tf.keras.regularizers.l1_l2(l1_reg,l2_reg)
                    )

    lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
        learning_rate, decay_steps = 4000, decay_rate = rate_decay, staircase = True)
    
    model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = lr_schedule), loss = tf.keras.losses.MeanAbsolutePercentageError(), 
                  metrics = [tf.keras.metrics.MeanSquaredError()])

    return model

# %% [markdown]
# ## 1.1 Using Random Tuner:

# %%
dims = [1, 4, 7, 10, 13, 16]
best_models_history_rn = []
best_hp_lists_rn = []
begin_train_rn, end_train_rn = [0]*len(dims),[0]*len(dims)

for i, dim in enumerate(dims):
    train_ds, valid_ds, test_ds = pipeline1(dataframes_list[i].to_numpy(), scaling=True, prefetch=True)

    print(f"Start training for basket option with size {dim}:")

    random_tuner = kt.RandomSearch(
    hypermodel=tuned_model_hs, # the hypermodel to tune # can be tuneLR or tuneLayer
    objective="val_loss", # the objective to optimize
    max_trials=3, # the maximum number of trials to run
    executions_per_trial=2, # the number of models generated on each trial
    overwrite=True, # whether to overwrite previous trials
    directory="hyperparams/RandomSearch", # the directory to save the trials
    project_name=f"basket_option_{dim}", # the name of the project
    )  

    random_tuner.search(train_ds, epochs = 5, validation_data = valid_ds)    

    best_hp_lists_rn.append(random_tuner.get_best_hyperparameters(1)[0])
    models = random_tuner.get_best_models(num_models=1)
    best_model = models[0]
    
    begin_train_rn[i] = time.time()
    history = best_model.fit(train_ds, epochs = 10, validation_data = valid_ds)
    end_train_rn[i] = time.time()
    best_models_history_rn.append(history)
# Out:
# Trial 3 Complete [00h 00m 04s]
# val_loss: 460753.625
#
# Best val_loss So Far: 460753.625
# Total elapsed time: 00h 00m 12s
# Epoch 1/10
# 25/25 [==============================] - 1s 9ms/step - loss: 10146371.0000 - mean_squared_error: 0.1016 - val_loss: 4666153.0000 - val_mean_squared_error: 0.0273
# Epoch 2/10
# 25/25 [==============================] - 0s 4ms/step - loss: 7636520.5000 - mean_squared_error: 0.0827 - val_loss: 156027.7656 - val_mean_squared_error: 0.0046
# Epoch 3/10
# 25/25 [==============================] - 0s 3ms/step - loss: 6155944.5000 - mean_squared_error: 0.0446 - val_loss: 1498681.0000 - val_mean_squared_error: 0.0023
# Epoch 4/10
# 25/25 [==============================] - 0s 3ms/step - loss: 6680031.5000 - mean_squared_error: 0.0378 - val_loss: 1119015.5000 - val_mean_squared_error: 0.0026
# Epoch 5/10
# 25/25 [==============================] - 0s 3ms/step - loss: 4636922.0000 - mean_squared_error: 0.0265 - val_loss: 2540093.5000 - val_mean_squared_error: 0.0026
# Epoch 6/10
# 25/25 [==============================] - 0s 3ms/step - loss: 5513703.5000 - mean_squared_error: 0.0289 - val_loss: 1795259.5000 - val_mean_squared_error: 0.0101
# Epoch 7/10
# 25/25 [==============================] - 0s 3ms/step - loss: 4861879.5000 - mean_squared_error: 0.0239 - val_loss: 918479.5000 - val_mean_squared_error: 0.0028
# Epoch 8/10
# 25/25 [==============================] - 0s 3ms/step - loss: 3595457.5000 - mean_squared_error: 0.0157 - val_loss: 94554.0078 - val_mean_squared_error: 0.0045
# Epoch 9/10
# 25/25 [==============================] - 0s 4ms/step - loss: 2627512.7500 - mean_squared_error: 0.0154 - val_loss: 166183.0156 - val_mean_squared_error: 0.0039
# Epoch 10/10
# 25/25 [==============================] - 0s 3ms/step - loss: 2898077.5000 - mean_squared_error: 0.0117 - val_loss: 790504.0625 - val_mean_squared_error: 0.0029

# %% [markdown]
# The best hyperparameters:

# %%
pd.DataFrame([best_hp_lists_rn[i].values for i in range(len(dims))], index = dims)
# Out:
#     num_layers activation  learning_rate  rate_decay  l1_regularizer  \
# 1            5    sigmoid       0.003218    0.869513    9.561609e-08
# 4            2        elu       0.005152    0.973258    2.327540e-07
# 7            3       tanh       0.008316    0.897428    2.257280e-07
# 10           4       tanh       0.004704    0.929727    2.355205e-07
# 13           2       relu       0.001846    0.868290    8.067674e-08
# 16           3    sigmoid       0.005298    0.920690    2.470968e-07
#
#     batchnorm  units_1  dropout_1  units_2  dropout_2  units_3  dropout_3  \
# 1       False        7        0.2        5        0.1        7        0.4
# 4       False        5        0.3        7        0.1        5        0.3
# 7        True        7        0.0        5        0.0        5        0.0
# 10       True        5        0.4        6        0.1        7        0.1
# 13      False        6        0.1        6        0.4        6        0.3
# 16      False        5        0.3        6        0.5        6        0.4
#
#     units_4  dropout_4  units_5  dropout_5
# 1       5.0        0.4      5.0        0.0
# 4       7.0        0.0      NaN        NaN
# 7       NaN        NaN      NaN        NaN
# 10      5.0        0.0      NaN        NaN
# 13      NaN        NaN      NaN        NaN
# 16      5.0        0.2      6.0        0.4

# %%
for i,dim in enumerate(dims):
  print(f"The best validation MSE for basket of size {dim}: \n  {min(best_models_history_rn[i].history['val_mean_squared_error'])}")
  # print(f"The best validation MAPE for basket of size {dim}: \n  {min(best_models_history[i].history['val_mean_absolute_percentage_error'])}")
# Out:
# The best validation MSE for basket of size 1:
#   0.0015863908920437098
# The best validation MSE for basket of size 4:
#   0.008871371857821941
# The best validation MSE for basket of size 7:
#   0.023466937243938446
# The best validation MSE for basket of size 10:
#   0.0013349620858207345
# The best validation MSE for basket of size 13:
#   0.013999377377331257
# The best validation MSE for basket of size 16:
#   0.0023309816606342793

# %%
for i,dim in enumerate(dims):
  print(f"Training time for dim {dim}: {end_train_rn[i] - begin_train_rn[i]} seconds")
# Out:
# Training time for dim 1: 3.123819589614868 seconds
# Training time for dim 4: 4.965630531311035 seconds
# Training time for dim 7: 4.7338645458221436 seconds
# Training time for dim 10: 2.6725995540618896 seconds
# Training time for dim 13: 2.86281156539917 seconds
# Training time for dim 16: 2.6475534439086914 seconds

# %% [markdown]
# ## 1.2 Using Hyperband Tuner:

# %%
dims = [1, 4, 7, 10, 13, 16]
best_models_history_hb = []
best_hp_lists_hb = []
begin_train_hb, end_train_hb = [0]*len(dims),[0]*len(dims)

for i, dim in enumerate(dims):
    train_ds, valid_ds, test_ds = pipeline1(dataframes_list[i].to_numpy(), scaling=True, prefetch=True)

    print(f"Start training for basket option with size {dim}:")

    Hyperband_tuner = kt.Hyperband(
    hypermodel=tuned_model_hs, # the hypermodel to tune # can be tuneLR or tuneLayer
    objective="val_loss", # the objective to optimize
    max_epochs=10,
    factor=3,
    directory="hyperparams/HyperbandSearch", # the directory to save the trials
    project_name=f"basket_option_{dim}", # the name of the project
    )  

    Hyperband_tuner.search(train_ds, epochs = 5, validation_data = valid_ds)    

    best_hp_lists_hb.append(Hyperband_tuner.get_best_hyperparameters(1)[0])
    models = Hyperband_tuner.get_best_models(num_models=1)
    best_model = models[0]
    
    begin_train_hb[i] = time.time()
    history = best_model.fit(train_ds, epochs = 10, validation_data = valid_ds)
    end_train_hb[i] = time.time()
    best_models_history_hb.append(history)
# Out:
# Trial 30 Complete [00h 00m 03s]
# val_loss: 447959.59375
#
# Best val_loss So Far: 38129.68359375
# Total elapsed time: 00h 01m 17s
# Epoch 1/10
# 25/25 [==============================] - 1s 9ms/step - loss: 271396.0000 - mean_squared_error: 0.0061 - val_loss: 51241.2266 - val_mean_squared_error: 0.0034
# Epoch 2/10
# 25/25 [==============================] - 0s 3ms/step - loss: 139501.4844 - mean_squared_error: 0.0060 - val_loss: 286670.0625 - val_mean_squared_error: 0.0031
# Epoch 3/10
# 25/25 [==============================] - 0s 3ms/step - loss: 195842.6406 - mean_squared_error: 0.0059 - val_loss: 370529.0000 - val_mean_squared_error: 0.0030
# Epoch 4/10
# 25/25 [==============================] - 0s 3ms/step - loss: 144811.7500 - mean_squared_error: 0.0058 - val_loss: 265202.6875 - val_mean_squared_error: 0.0039
# Epoch 5/10
# 25/25 [==============================] - 0s 3ms/step - loss: 216428.5000 - mean_squared_error: 0.0059 - val_loss: 424619.1562 - val_mean_squared_error: 0.0041
# Epoch 6/10
# 25/25 [==============================] - 0s 3ms/step - loss: 218502.2969 - mean_squared_error: 0.0058 - val_loss: 274760.4375 - val_mean_squared_error: 0.0039
# Epoch 7/10
# 25/25 [==============================] - 0s 4ms/step - loss: 150583.8594 - mean_squared_error: 0.0060 - val_loss: 59484.5000 - val_mean_squared_error: 0.0034
# Epoch 8/10
# 25/25 [==============================] - 0s 4ms/step - loss: 59078.7812 - mean_squared_error: 0.0058 - val_loss: 457570.5938 - val_mean_squared_error: 0.0029
# Epoch 9/10
# 25/25 [==============================] - 0s 3ms/step - loss: 209745.7344 - mean_squared_error: 0.0057 - val_loss: 391330.8125 - val_mean_squared_error: 0.0030
# Epoch 10/10
# 25/25 [==============================] - 0s 3ms/step - loss: 218623.5625 - mean_squared_error: 0.0062 - val_loss: 208226.9375 - val_mean_squared_error: 0.0032

# %% [markdown]
# Best hyperparameters:

# %%
pd.DataFrame([best_hp_lists_hb[i].values for i in range(len(dims))], index = dims)
# Out:
#     num_layers activation  learning_rate  rate_decay  l1_regularizer  \
# 1            2       relu       0.005872    0.961157    2.460751e-07
# 4            5       relu       0.007870    0.918098    2.744735e-07
# 7            3       relu       0.004759    0.859409    2.223006e-07
# 10           5    sigmoid       0.001955    0.860591    1.043340e-07
# 13           4       relu       0.005957    0.967706    1.358656e-07
# 16           2       relu       0.005348    0.908735    1.606016e-07
#
#     batchnorm  units_1  dropout_1  units_2  dropout_2  ...  dropout_3  \
# 1       False        7        0.2        6        0.3  ...        0.3
# 4       False        7        0.0        6        0.3  ...        0.1
# 7       False        5        0.3        6        0.1  ...        0.2
# 10      False        6        0.0        6        0.4  ...        0.3
# 13      False        5        0.0        5        0.2  ...        0.2
# 16      False        5        0.2        6        0.1  ...        0.0
#
#     units_4  dropout_4  units_5  dropout_5  tuner/epochs  tuner/initial_epoch  \
# 1         6        0.3      5.0        0.4            10                    4
# 4         5        0.0      7.0        0.1             4                    2
# 7         6        0.1      6.0        0.4            10                    4
# 10        7        0.0      6.0        0.2            10                    0
# 13        7        0.4      NaN        NaN            10                    0
# 16        7        0.3      6.0        0.0             4                    0
#
#     tuner/bracket  tuner/round  tuner/trial_id
# 1               1            1            0019
# 4               2            1            0009
# 7               1            1            0023
# 10              0            0             NaN
# 13              0            0             NaN
# 16              1            0             NaN
#
# [6 rows x 21 columns]

# %%
for i,dim in enumerate(dims):
  print(f"The best validation MSE for basket of size {dim}: \n  {min(best_models_history_hb[i].history['val_mean_squared_error'])}")
  # print(f"The best validation MAPE for basket of size {dim}: \n  {min(best_models_history[i].history['val_mean_absolute_percentage_error'])}")
# Out:
# The best validation MSE for basket of size 1:
#   0.0004873159050475806
# The best validation MSE for basket of size 4:
#   0.005056868307292461
# The best validation MSE for basket of size 7:
#   0.03680519759654999
# The best validation MSE for basket of size 10:
#   6.294813647400588e-05
# The best validation MSE for basket of size 13:
#   0.018639778718352318
# The best validation MSE for basket of size 16:
#   0.002898908220231533

# %%
for i,dim in enumerate(dims):
  print(f"Training time for dim {dim}: {end_train_hb[i] - begin_train_hb[i]} seconds")
# Out:
# Training time for dim 1: 2.1893463134765625 seconds
# Training time for dim 4: 2.9390745162963867 seconds
# Training time for dim 7: 2.420423746109009 seconds
# Training time for dim 10: 4.247692584991455 seconds
# Training time for dim 13: 2.458421230316162 seconds
# Training time for dim 16: 2.228080987930298 seconds

# %% [markdown]
# ## 1.3 Using Bayesian Optimization

# %%
dims = [1, 4, 7, 10, 13, 16]
best_models_history_bo = []
best_hp_lists_bo = []
begin_train_bo, end_train_bo = [0]*len(dims),[0]*len(dims)

for i, dim in enumerate(dims):
    train_ds, valid_ds, test_ds = pipeline1(dataframes_list[i].to_numpy(), scaling=True, prefetch=True)

    print(f"Start training for basket option with size {dim}:")

    bayes_tuner = kt.BayesianOptimization(
    hypermodel=tuned_model_hs, # the hypermodel to tune # can be tuneLR or tuneLayer
    objective="val_loss", # the objective to optimize
    max_trials=3,
    directory="hyperparams/BayesianOptimization", # the directory to save the trials
    project_name=f"basket_option_{dim}", # the name of the project
    )  

    bayes_tuner.search(train_ds, epochs = 5, validation_data = valid_ds)    

    best_hp_lists_bo.append(bayes_tuner.get_best_hyperparameters(1)[0])
    models = bayes_tuner.get_best_models(num_models=1)
    best_model = models[0]
    
    begin_train_bo[i] = time.time()
    history = best_model.fit(train_ds, epochs = 10, validation_data = valid_ds)
    end_train_bo[i] = time.time()
    best_models_history_bo.append(history)
# Out:
# (800, 10) (100, 10) (100, 10)
# Start training for basket option with size 1:
# Epoch 1/10
# 25/25 [==============================] - 2s 13ms/step - loss: 1751156.0000 - mean_squared_error: 0.0101 - val_loss: 2384749.5000 - val_mean_squared_error: 0.0062
# Epoch 2/10
# 25/25 [==============================] - 0s 4ms/step - loss: 2626196.5000 - mean_squared_error: 0.0088 - val_loss: 1348370.8750 - val_mean_squared_error: 0.0035
# Epoch 3/10
# 25/25 [==============================] - 0s 4ms/step - loss: 1976045.2500 - mean_squared_error: 0.0095 - val_loss: 1906662.2500 - val_mean_squared_error: 0.0044
# Epoch 4/10
# 25/25 [==============================] - 0s 4ms/step - loss: 1620164.5000 - mean_squared_error: 0.0085 - val_loss: 929981.3750 - val_mean_squared_error: 0.0036
# Epoch 5/10
# 25/25 [==============================] - 0s 4ms/step - loss: 1952873.6250 - mean_squared_error: 0.0070 - val_loss: 1280106.3750 - val_mean_squared_error: 0.0036
# Epoch 6/10
# 25/25 [==============================] - 0s 4ms/step - loss: 2059715.0000 - mean_squared_error: 0.0131 - val_loss: 966857.1250 - val_mean_squared_error: 0.0039
# Epoch 7/10
# 25/25 [==============================] - 0s 4ms/step - loss: 2309103.0000 - mean_squared_error: 0.0079 - val_loss: 1324963.2500 - val_mean_squared_error: 0.0036
# Epoch 8/10
# 25/25 [==============================] - 0s 4ms/step - loss: 1905252.0000 - mean_squared_error: 0.0102 - val_loss: 849767.0625 - val_mean_squared_error: 0.0064
# Epoch 9/10
# 25/25 [==============================] - 0s 4ms/step - loss: 1436141.5000 - mean_squared_error: 0.0076 - val_loss: 767584.2500 - val_mean_squared_error: 0.0081
# Epoch 10/10
# 25/25 [==============================] - 0s 4ms/step - loss: 1165512.7500 - mean_squared_error: 0.0082 - val_loss: 437915.3125 - val_mean_squared_error: 0.0044
# (800, 16) (100, 16) (100, 16)
# Start training for basket option with size 4:
# Epoch 1/10
# 25/25 [==============================] - 1s 8ms/step - loss: 928343.3750 - mean_squared_error: 0.0167 - val_loss: 596261.1250 - val_mean_squared_error: 0.0192
# Epoch 2/10
# 25/25 [==============================] - 0s 4ms/step - loss: 1153328.1250 - mean_squared_error: 0.0176 - val_loss: 314765.0938 - val_mean_squared_error: 0.0222
# Epoch 3/10
# 25/25 [==============================] - 0s 3ms/step - loss: 593683.8125 - mean_squared_error: 0.0151 - val_loss: 176751.4219 - val_mean_squared_error: 0.0220
# Epoch 4/10
# 25/25 [==============================] - 0s 3ms/step - loss: 454575.6875 - mean_squared_error: 0.0153 - val_loss: 1073028.7500 - val_mean_squared_error: 0.0181
# Epoch 5/10
# 25/25 [==============================] - 0s 4ms/step - loss: 832761.2500 - mean_squared_error: 0.0169 - val_loss: 1251081.0000 - val_mean_squared_error: 0.0176
# Epoch 6/10
# 25/25 [==============================] - 0s 3ms/step - loss: 830005.2500 - mean_squared_error: 0.0154 - val_loss: 86134.0625 - val_mean_squared_error: 0.0210
# Epoch 7/10
# 25/25 [==============================] - 0s 4ms/step - loss: 321298.8438 - mean_squared_error: 0.0159 - val_loss: 279492.7500 - val_mean_squared_error: 0.0201
# Epoch 8/10
# 25/25 [==============================] - 0s 4ms/step - loss: 354840.5625 - mean_squared_error: 0.0154 - val_loss: 610262.3750 - val_mean_squared_error: 0.0191
# Epoch 9/10
# 25/25 [==============================] - 0s 4ms/step - loss: 443315.8125 - mean_squared_error: 0.0157 - val_loss: 610229.1250 - val_mean_squared_error: 0.0192
# Epoch 10/10
# 25/25 [==============================] - 0s 4ms/step - loss: 433700.0312 - mean_squared_error: 0.0152 - val_loss: 821560.0625 - val_mean_squared_error: 0.0242
# (800, 22) (100, 22) (100, 22)
# Start training for basket option with size 7:
# Epoch 1/10
# 25/25 [==============================] - 1s 8ms/step - loss: 83399.4766 - mean_squared_error: 0.0435 - val_loss: 124198.5703 - val_mean_squared_error: 0.0512
# Epoch 2/10
# 25/25 [==============================] - 0s 4ms/step - loss: 85179.0469 - mean_squared_error: 0.0435 - val_loss: 115853.7734 - val_mean_squared_error: 0.0511
# Epoch 3/10
# 25/25 [==============================] - 0s 3ms/step - loss: 84060.8438 - mean_squared_error: 0.0435 - val_loss: 103851.9219 - val_mean_squared_error: 0.0511
# Epoch 4/10
# 25/25 [==============================] - 0s 4ms/step - loss: 83615.3828 - mean_squared_error: 0.0425 - val_loss: 210625.4844 - val_mean_squared_error: 0.0514
# Epoch 5/10
# 25/25 [==============================] - 0s 4ms/step - loss: 97142.7422 - mean_squared_error: 0.0437 - val_loss: 124789.8672 - val_mean_squared_error: 0.0502
# Epoch 6/10
# 25/25 [==============================] - 0s 3ms/step - loss: 108164.3828 - mean_squared_error: 0.0436 - val_loss: 88582.9922 - val_mean_squared_error: 0.0504
# Epoch 7/10
# 25/25 [==============================] - 0s 3ms/step - loss: 64948.0586 - mean_squared_error: 0.0433 - val_loss: 207170.1406 - val_mean_squared_error: 0.0515
# Epoch 8/10
# 25/25 [==============================] - 0s 3ms/step - loss: 94590.8203 - mean_squared_error: 0.0438 - val_loss: 21547.2344 - val_mean_squared_error: 0.0506
# Epoch 9/10
# 25/25 [==============================] - 0s 4ms/step - loss: 29130.4395 - mean_squared_error: 0.0435 - val_loss: 135859.0938 - val_mean_squared_error: 0.0502
# Epoch 10/10
# 25/25 [==============================] - 0s 4ms/step - loss: 112679.3906 - mean_squared_error: 0.0436 - val_loss: 330969.6875 - val_mean_squared_error: 0.0519
# (800, 28) (100, 28) (100, 28)
# Start training for basket option with size 10:
# Epoch 1/10
# 25/25 [==============================] - 1s 8ms/step - loss: 9410969.0000 - mean_squared_error: 0.0902 - val_loss: 536660.7500 - val_mean_squared_error: 0.0015
# Epoch 2/10
# 25/25 [==============================] - 0s 4ms/step - loss: 3039529.0000 - mean_squared_error: 0.0385 - val_loss: 488218.9062 - val_mean_squared_error: 3.2583e-04
# Epoch 3/10
# 25/25 [==============================] - 0s 4ms/step - loss: 1119731.2500 - mean_squared_error: 0.0200 - val_loss: 9878.4648 - val_mean_squared_error: 1.4941e-04
# Epoch 4/10
# 25/25 [==============================] - 0s 4ms/step - loss: 780994.3750 - mean_squared_error: 0.0124 - val_loss: 176342.5156 - val_mean_squared_error: 9.1487e-05
# Epoch 5/10
# 25/25 [==============================] - 0s 4ms/step - loss: 645339.5000 - mean_squared_error: 0.0070 - val_loss: 342961.4375 - val_mean_squared_error: 5.1426e-04
# Epoch 6/10
# 25/25 [==============================] - 0s 4ms/step - loss: 832967.6250 - mean_squared_error: 0.0081 - val_loss: 774430.5625 - val_mean_squared_error: 0.0014
# Epoch 7/10
# 25/25 [==============================] - 0s 3ms/step - loss: 926455.1250 - mean_squared_error: 0.0059 - val_loss: 691805.1250 - val_mean_squared_error: 0.0013
# Epoch 8/10
# 25/25 [==============================] - 0s 3ms/step - loss: 583579.7500 - mean_squared_error: 0.0043 - val_loss: 686395.6250 - val_mean_squared_error: 0.0012
# Epoch 9/10
# 25/25 [==============================] - 0s 4ms/step - loss: 620446.5625 - mean_squared_error: 0.0038 - val_loss: 451839.9688 - val_mean_squared_error: 6.7934e-04
# Epoch 10/10
# 25/25 [==============================] - 0s 4ms/step - loss: 258171.0000 - mean_squared_error: 0.0035 - val_loss: 205960.6875 - val_mean_squared_error: 3.1409e-04
# (800, 34) (100, 34) (100, 34)
# Start training for basket option with size 13:
# Epoch 1/10
# 25/25 [==============================] - 1s 8ms/step - loss: 302338.5625 - mean_squared_error: 0.0167 - val_loss: 367294.9062 - val_mean_squared_error: 0.0152
# Epoch 2/10
# 25/25 [==============================] - 0s 4ms/step - loss: 83078.3203 - mean_squared_error: 0.0163 - val_loss: 359113.3125 - val_mean_squared_error: 0.0153
# Epoch 3/10
# 25/25 [==============================] - 0s 4ms/step - loss: 48874.3555 - mean_squared_error: 0.0167 - val_loss: 470119.4062 - val_mean_squared_error: 0.0146
# Epoch 4/10
# 25/25 [==============================] - 0s 4ms/step - loss: 143117.4844 - mean_squared_error: 0.0168 - val_loss: 397046.4062 - val_mean_squared_error: 0.0149
# Epoch 5/10
# 25/25 [==============================] - 0s 4ms/step - loss: 86467.8828 - mean_squared_error: 0.0166 - val_loss: 346551.4375 - val_mean_squared_error: 0.0150
# Epoch 6/10
# 25/25 [==============================] - 0s 3ms/step - loss: 41304.1719 - mean_squared_error: 0.0165 - val_loss: 318317.8438 - val_mean_squared_error: 0.0151
# Epoch 7/10
# 25/25 [==============================] - 0s 3ms/step - loss: 98528.6406 - mean_squared_error: 0.0165 - val_loss: 321062.0312 - val_mean_squared_error: 0.0151
# Epoch 8/10
# 25/25 [==============================] - 0s 3ms/step - loss: 181707.0938 - mean_squared_error: 0.0164 - val_loss: 351357.1250 - val_mean_squared_error: 0.0152
# Epoch 9/10
# 25/25 [==============================] - 0s 3ms/step - loss: 147042.4531 - mean_squared_error: 0.0166 - val_loss: 322200.2500 - val_mean_squared_error: 0.0151
# Epoch 10/10
# 25/25 [==============================] - 0s 3ms/step - loss: 119832.0234 - mean_squared_error: 0.0166 - val_loss: 522522.4688 - val_mean_squared_error: 0.0161
# (800, 40) (100, 40) (100, 40)
# Start training for basket option with size 16:
# Epoch 1/10
# 25/25 [==============================] - 1s 10ms/step - loss: 3862581.5000 - mean_squared_error: 0.0137 - val_loss: 3011061.7500 - val_mean_squared_error: 0.0248
# Epoch 2/10
# 25/25 [==============================] - 0s 3ms/step - loss: 2002101.5000 - mean_squared_error: 0.0102 - val_loss: 640266.8750 - val_mean_squared_error: 0.0074
# Epoch 3/10
# 25/25 [==============================] - 0s 4ms/step - loss: 2458412.5000 - mean_squared_error: 0.0118 - val_loss: 2375115.7500 - val_mean_squared_error: 0.0148
# Epoch 4/10
# 25/25 [==============================] - 0s 3ms/step - loss: 2107377.0000 - mean_squared_error: 0.0127 - val_loss: 1974421.8750 - val_mean_squared_error: 0.0048
# Epoch 5/10
# 25/25 [==============================] - 0s 3ms/step - loss: 1882898.1250 - mean_squared_error: 0.0077 - val_loss: 787097.4375 - val_mean_squared_error: 0.0077
# Epoch 6/10
# 25/25 [==============================] - 0s 4ms/step - loss: 1678687.0000 - mean_squared_error: 0.0071 - val_loss: 451390.4688 - val_mean_squared_error: 0.0094
# Epoch 7/10
# 25/25 [==============================] - 0s 4ms/step - loss: 1431861.8750 - mean_squared_error: 0.0082 - val_loss: 238171.0469 - val_mean_squared_error: 0.0069
# Epoch 8/10
# 25/25 [==============================] - 0s 3ms/step - loss: 1309467.1250 - mean_squared_error: 0.0069 - val_loss: 678822.3125 - val_mean_squared_error: 0.0091
# Epoch 9/10
# 25/25 [==============================] - 0s 4ms/step - loss: 1232525.6250 - mean_squared_error: 0.0062 - val_loss: 947670.6250 - val_mean_squared_error: 0.0041
# Epoch 10/10
# 25/25 [==============================] - 0s 3ms/step - loss: 1622156.6250 - mean_squared_error: 0.0067 - val_loss: 567868.9375 - val_mean_squared_error: 0.0097

# %% [markdown]
# Best hyperparameters:

# %%
pd.DataFrame([best_hp_lists_bo[i].values for i in range(len(dims))], index = dims)
# Out:
#     num_layers activation  learning_rate  rate_decay  l1_regularizer  \
# 1            4       relu       0.006859    0.941751    2.889118e-07
# 4            2    sigmoid       0.009804    0.903555    2.336900e-07
# 7            2       relu       0.006772    0.889963    2.878761e-07
# 10           1       relu       0.005080    0.949280    8.696250e-08
# 13           2       relu       0.007673    0.884123    2.020740e-07
# 16           4        elu       0.009133    0.975671    1.267550e-07
#
#     batchnorm  units_1  dropout_1  units_2  dropout_2  units_3  dropout_3  \
# 1        True        6        0.3        5        0.0      5.0        0.0
# 4       False        6        0.4        5        0.0      NaN        NaN
# 7       False        6        0.3        5        0.0      NaN        NaN
# 10       True        7        0.5        5        0.2      7.0        0.4
# 13      False        6        0.5        5        0.3      6.0        0.4
# 16      False        6        0.4        5        0.0      5.0        0.0
#
#     units_4  dropout_4
# 1       5.0        0.0
# 4       NaN        NaN
# 7       NaN        NaN
# 10      7.0        0.1
# 13      5.0        0.5
# 16      5.0        0.0

# %%
for i,dim in enumerate(dims):
  print(f"The best validation MSE for basket of size {dim}: \n  {min(best_models_history_bo[i].history['val_mean_squared_error'])}")
  # print(f"The best validation MAPE for basket of size {dim}: \n  {min(best_models_history_bo[i].history['val_mean_absolute_percentage_error'])}")
# Out:
# The best validation MSE for basket of size 1:
#   0.003528574714437127
# The best validation MSE for basket of size 4:
#   0.017625294625759125
# The best validation MSE for basket of size 7:
#   0.05020308122038841
# The best validation MSE for basket of size 10:
#   9.148690878646448e-05
# The best validation MSE for basket of size 13:
#   0.01464453898370266
# The best validation MSE for basket of size 16:
#   0.004053478594869375

# %%
for i,dim in enumerate(dims):
  print(f"Training time for dim {dim}: {end_train_bo[i] - begin_train_bo[i]} seconds")
# Out:
# Training time for dim 1: 3.450819969177246 seconds
# Training time for dim 4: 2.2184031009674072 seconds
# Training time for dim 7: 2.136911392211914 seconds
# Training time for dim 10: 2.1807596683502197 seconds
# Training time for dim 13: 2.1221179962158203 seconds
# Training time for dim 16: 2.3997867107391357 seconds
